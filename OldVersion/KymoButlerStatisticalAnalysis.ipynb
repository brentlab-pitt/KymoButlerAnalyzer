# %% [markdown]
# # Kymograph Statistical Analysis
#
# After running KymoButlerDataProccessing.ipynb, there should be a folder within each folder of kymographs called kymoresults, in this folder is the compiled and processed data for each directional metric that is outputted from KymoButler (AI program that analyzes kymographs made by Max Jakobs: https://github.com/MaxJakobs/KymoButler). Now the following scripts will perform statistical analysis across different conditions of data. It will output graphs displaying results from each metric and the statistical analysis (t-tests, ANOVA, mean).

# %% [markdown]
# # Statistical Analysis for 1 Replicate
#
# Intended to be used on one experiment that has several conditions of data (cannot perform t-tests on one condition of data). Choose directory that contains a folder for each condition of data. Script will loop through each folder, open kymoresults folder, then create take data and create a graph for each metric, and perform t-tests and ANOVA on the MEAN results from each cell. Saves graphs and analysis results in new folder called 'results' in selected directory

# %%
import os
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, f_oneway
from tkinter import filedialog, Tk 
import numpy as np

def analyze_data(directory, condition_folders):
    """
    Analyze the data in the specified directory for the given condition folders.

    Parameters:
        directory (str): The path to the directory containing the CSV files.
        condition_folders (list): List of folder names for different conditions.
    """

    # Create a folder named "results" in the selected directory
    results_folder = os.path.join(directory, "results")
    os.makedirs(results_folder, exist_ok=True)

    # Check if all required folders exist
    condition_paths = [os.path.join(directory, folder, "kymoresults") for folder in condition_folders]
    if not all(os.path.exists(folder) for folder in condition_paths):
        print("One or more required folders are missing.")
        return

    significant_tests = False

    # Define the CSV files to analyze
    csv_files = ['ANTdisplacementresults.csv', 'ANTdurationresults.csv', 'ANTframe2frameresults.csv',
                 'ANTstart2endresults.csv', 'RETdisplacementresults.csv', 'RETdurationresults.csv',
                 'RETframe2frameresults.csv', 'RETstart2endresults.csv', 'TOTALdisplacementresults.csv',
                 'TOTALdurationresults.csv', 'TOTALframe2frameresults.csv', 'TOTALstart2endresults.csv']

    for file in csv_files:
        # Read data from each CSV file into dataframes for each condition
        condition_dfs = []
        for folder in condition_paths:
            condition_dfs.append(pd.read_csv(os.path.join(folder, file)))
            #print('conditinon_dfs', condition_dfs)

        # Calculate mean summary statistics for each condition
        mean_summaries = [df.describe().loc['mean'] for df in condition_dfs]
        #print('mean_summaries', mean_summaries)

        # Combine mean summary statistics across conditions
        combined_summary = pd.concat(mean_summaries, axis=1)

        # Label combined_summary with condition folder names
        combined_summary.columns = condition_folders



        # Perform t-tests between conditions
        t_test_results = []
        for i in range(len(condition_folders)):
            for j in range(i+1, len(condition_folders)):
                
                #condition_folder[i] is going to return the name of one of the condition folders, so then you can recall the name of the condition folder column in combined_summary
                t_stat, p_value = ttest_ind(combined_summary[condition_folders[i]], combined_summary[condition_folders[j]],nan_policy='omit')
                t_test_results.append((f"T-test between {condition_folders[i]} and {condition_folders[j]} ({file}):",
                                       f"t-statistic: {t_stat}, p-value: {p_value}"))
                print(f"\nT-test between {condition_folders[i]} and {condition_folders[j]} ({file}):")
                print(f"t-statistic: {t_stat}, p-value: {p_value}")

                # Check if the test is significant
                if p_value < 0.05:
                    significant_tests = True

        
        # Drop rows with missing values
        clean_combined=combined_summary.dropna()

        #ANOVA test
        anova_f_stat, anova_p_value = f_oneway(*[clean_combined[column] for column in clean_combined.columns])
        anova_result = f"ANOVA test ({file}): F-statistic: {anova_f_stat}, p-value: {anova_p_value}"

        print(f"\nANOVA test ({file}):")
        print(f"F-statistic: {anova_f_stat}, p-value: {anova_p_value}")
        
        # Check if the test is significant
        if anova_p_value < 0.05:
            significant_tests = True
        
        # Write the results to a text file
        with open(os.path.join(results_folder, f"{file}_test_results.txt"), "w") as f:
            for result in t_test_results:
                f.write(result[0] + "\n")
                f.write(result[1] + "\n")
            f.write("\n")
            f.write(anova_result + "\n")
            f.write("\n")


        # Reshape the data for the violin plot
        combined_summary = combined_summary.reset_index().melt(id_vars='index', var_name='Condition', value_name='Mean')

        palette1 = sns.color_palette("flare", n_colors=len(condition_folders))
        #palette1=['black', 'fuchsia', 'darkviolet', 'limegreen', 'deepskyblue', 'red'] #add more colors or rearrange as necessary

        # Create violin plot
        plt.figure(figsize=(6, 6))

        # Draw violin plot with mean line
        sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
                    palette=palette1, linewidth=0, hue='Condition', legend=False,
                    inner=None)  # Remove inner annotations to add mean line separately

        # Calculate mean for each group
        means = combined_summary.groupby('Condition')['Mean'].mean()
        # Sort means Series based on the order of condition_folders
        means = means.reindex(condition_folders)
        print("Means:", means)  # Print mean values
        print("Condition folders:", condition_folders)  # Print condition folder names
        for i, mean_val in enumerate(means):
            print(f"Plotting mean {mean_val} for condition {condition_folders[i]} at position {i}")
            plt.plot(i, mean_val, marker='D', color='black')  # Draw mean point


        plt.title(f'{"Anterograde" if "ANT" in file else "Retrograde" if "RET" in file else "Total"} '
                f'{"Duration" if "duration" in file else "Displacement" if "displacement" in file else "Frame2Frame Velocity" if "frame2frame" in file else "Start2End Velocity"}', 
                fontsize=16, fontweight='bold')

        plt.ylabel(f'{"Track Mean Velocity [µm/sec]" if "2" in file else "Track Duration [sec]" if "duration" in file else "Track Displacement [µm]"} ', fontsize=16, fontweight='bold')
        plt.xlabel('')
        plt.xticks(np.arange(len(condition_folders)), condition_folders, fontsize=12, fontweight='bold')  # Set ticks at each group
        plt.yticks(fontsize=12, fontweight='bold')
        plt.gca().spines['top'].set_visible(False)
        plt.gca().spines['right'].set_visible(False)
        plt.gca().spines['left'].set_linewidth(2)
        plt.gca().spines['bottom'].set_linewidth(2)

        
        # Save the plot to the results folder
        plt.savefig(os.path.join(results_folder, f'{"Anterograde" if "ANT" in file else "Retrograde" if "RET" in file else "Total"} '
                f'{"Duration" if "duration" in file else "Displacement" if "displacement" in file else "Frame2Frame Velocity" if "frame2frame" in file else "Start2End Velocity"}_summary.png'))

        plt.tight_layout()
        plt.show()



    # Print if any test was significant
    if significant_tests:
        print("\nAt least one test was significant.")
    else:
        print("\nNo test was significant.")


# Prompt the user for the number of conditions and their names
num_conditions = int(input("Enter the number of conditions: "))

# Check if the number of conditions is 1
if num_conditions == 1:
    print("T-tests and ANOVA tests cannot be performed on a single condition. Exiting program.")
    sys.exit()

condition_folders = []
for i in range(num_conditions):
    folder_name = input(f"Enter the folder name for condition {i+1}: ")
    condition_folders.append(folder_name)

# Create the tkinter window
root = Tk()
root.withdraw()  # Hide the main window

# Ask the user to select a directory
directory = filedialog.askdirectory(title="Select Directory Containing Folders")

# Perform analysis if a directory is selected
if directory:
    analyze_data(directory, condition_folders)
else:
    print("No directory selected.")
# Out:
# T-test between wt and 27del (ANTdisplacementresults.csv):
# t-statistic: -0.28152358775236186, p-value: 0.7813520755646126
#
# T-test between wt and 854 (ANTdisplacementresults.csv):
# t-statistic: -0.13199092641655444, p-value: 0.8965410711584182
#
# T-test between 27del and 854 (ANTdisplacementresults.csv):
# t-statistic: 0.22482634021692224, p-value: 0.8246469035396118
#
# ANOVA test (ANTdisplacementresults.csv):
# F-statistic: 0.16335121936194139, p-value: 0.8502291396713157
# Means: Condition
# wt       39.813634
# 27del    42.152117
# 854      40.943512
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 39.813633843748555 for condition wt at position 0
# Plotting mean 42.15211705577106 for condition 27del at position 1
# Plotting mean 40.94351153783387 for condition 854 at position 2
# T-test between wt and 27del (ANTdurationresults.csv):
# t-statistic: 0.8563819728309134, p-value: 0.40245847668513146
#
# T-test between wt and 854 (ANTdurationresults.csv):
# t-statistic: 0.5290279202953101, p-value: 0.603625842405278
#
# T-test between 27del and 854 (ANTdurationresults.csv):
# t-statistic: -0.3044190230507301, p-value: 0.7643000932697293
#
# ANOVA test (ANTdurationresults.csv):
# F-statistic: 0.7605548038756651, p-value: 0.47834393050707136
# Means: Condition
# wt       97.964144
# 27del    88.805842
# 854      91.575950
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 97.96414428528263 for condition wt at position 0
# Plotting mean 88.80584244946257 for condition 27del at position 1
# Plotting mean 91.57595019660677 for condition 854 at position 2
# T-test between wt and 27del (ANTframe2frameresults.csv):
# t-statistic: -0.082577959989922, p-value: 0.9350508933712138
#
# T-test between wt and 854 (ANTframe2frameresults.csv):
# t-statistic: -0.19226695723016327, p-value: 0.8498111164023252
#
# T-test between 27del and 854 (ANTframe2frameresults.csv):
# t-statistic: -0.16870218331754186, p-value: 0.8679121463556364
#
# ANOVA test (ANTframe2frameresults.csv):
# F-statistic: 0.064768401217733, p-value: 0.9374477667001462
# Means: Condition
# wt       0.901914
# 27del    0.919851
# 854      0.947356
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 0.9019144222862702 for condition wt at position 0
# Plotting mean 0.9198509703054211 for condition 27del at position 1
# Plotting mean 0.9473563545574907 for condition 854 at position 2
# T-test between wt and 27del (ANTstart2endresults.csv):
# t-statistic: -0.07950752695281287, p-value: 0.9374603922632196
#
# T-test between wt and 854 (ANTstart2endresults.csv):
# t-statistic: -0.19616331782399402, p-value: 0.8468081323683629
#
# T-test between 27del and 854 (ANTstart2endresults.csv):
# t-statistic: -0.17848505115231633, p-value: 0.8603355478881041
#
# ANOVA test (ANTstart2endresults.csv):
# F-statistic: 0.06396865303516316, p-value: 0.9381937854447943
# Means: Condition
# wt       0.848007
# 27del    0.864081
# 854      0.891207
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 0.8480066308690082 for condition wt at position 0
# Plotting mean 0.8640814106879598 for condition 27del at position 1
# Plotting mean 0.8912072724228373 for condition 854 at position 2
# T-test between wt and 27del (RETdisplacementresults.csv):
# t-statistic: 0.2531603333825289, p-value: 0.802863257253938
#
# T-test between wt and 854 (RETdisplacementresults.csv):
# t-statistic: -0.111402662615533, p-value: 0.9126017955742776
#
# T-test between 27del and 854 (RETdisplacementresults.csv):
# t-statistic: -0.5350888407981793, p-value: 0.5991373932363175
#
# ANOVA test (RETdisplacementresults.csv):
# F-statistic: 0.0075358849635049005, p-value: 0.9924947861123182
# Means: Condition
# wt       34.035037
# 27del    32.542138
# 854      34.715454
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 34.035036943515195 for condition wt at position 0
# Plotting mean 32.54213819751835 for condition 27del at position 1
# Plotting mean 34.71545443745885 for condition 854 at position 2
# T-test between wt and 27del (RETdurationresults.csv):
# t-statistic: 0.9589997018537291, p-value: 0.3496043850763787
#
# T-test between wt and 854 (RETdurationresults.csv):
# t-statistic: 0.838855120739951, p-value: 0.4131912246667113
#
# T-test between 27del and 854 (RETdurationresults.csv):
# t-statistic: -0.13379798433181453, p-value: 0.8950469138150723
#
# ANOVA test (RETdurationresults.csv):
# F-statistic: 0.6525044476990569, p-value: 0.5297329273277962
# Means: Condition
# wt       96.837740
# 27del    83.855569
# 854      84.758034
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 96.83774037250656 for condition wt at position 0
# Plotting mean 83.85556854349399 for condition 27del at position 1
# Plotting mean 84.7580339402844 for condition 854 at position 2
# T-test between wt and 27del (RETframe2frameresults.csv):
# t-statistic: 0.7634408840198793, p-value: 0.45457649884586937
#
# T-test between wt and 854 (RETframe2frameresults.csv):
# t-statistic: 0.5813548256172151, p-value: 0.568630228965939
#
# T-test between 27del and 854 (RETframe2frameresults.csv):
# t-statistic: -0.2749677278965671, p-value: 0.7864723348470932
#
# ANOVA test (RETframe2frameresults.csv):
# F-statistic: 0.258146953408997, p-value: 0.7745992479002878
# Means: Condition
# wt       0.846772
# 27del    0.698837
# 854      0.723442
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 0.846772282115311 for condition wt at position 0
# Plotting mean 0.6988367074108913 for condition 27del at position 1
# Plotting mean 0.7234415903217709 for condition 854 at position 2
# T-test between wt and 27del (RETstart2endresults.csv):
# t-statistic: 0.7588572647276095, p-value: 0.4572494465781971
#
# T-test between wt and 854 (RETstart2endresults.csv):
# t-statistic: 0.5929616386131094, p-value: 0.5610130296125768
#
# T-test between 27del and 854 (RETstart2endresults.csv):
# t-statistic: -0.23864745674693955, p-value: 0.8140748283589019
#
# ANOVA test (RETstart2endresults.csv):
# F-statistic: 0.267569436758786, p-value: 0.7674898742368613
# Means: Condition
# wt       0.799706
# 27del    0.662446
# 854      0.682518
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 0.7997059181096811 for condition wt at position 0
# Plotting mean 0.6624461323736064 for condition 27del at position 1
# Plotting mean 0.6825176220013209 for condition 854 at position 2
# T-test between wt and 27del (TOTALdisplacementresults.csv):
# t-statistic: -0.1383549022343008, p-value: 0.8914157677431487
#
# T-test between wt and 854 (TOTALdisplacementresults.csv):
# t-statistic: -0.14542112617872946, p-value: 0.8860886928497834
#
# T-test between 27del and 854 (TOTALdisplacementresults.csv):
# t-statistic: -0.022168354520140217, p-value: 0.9825575616217443
#
# ANOVA test (TOTALdisplacementresults.csv):
# F-statistic: 0.10553456225406092, p-value: 0.9002586204055564
# Means: Condition
# wt       36.129844
# 27del    37.080877
# 854      37.172482
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 36.12984413497062 for condition wt at position 0
# Plotting mean 37.08087693065909 for condition 27del at position 1
# Plotting mean 37.172482204766034 for condition 854 at position 2
# T-test between wt and 27del (TOTALdurationresults.csv):
# t-statistic: 1.0630019702788762, p-value: 0.30110570545589493
#
# T-test between wt and 854 (TOTALdurationresults.csv):
# t-statistic: 0.7977607363411148, p-value: 0.43601175082521704
#
# T-test between 27del and 854 (TOTALdurationresults.csv):
# t-statistic: -0.3317981942208847, p-value: 0.7438738074849733
#
# ANOVA test (TOTALdurationresults.csv):
# F-statistic: 0.9659435954621358, p-value: 0.3949348117646089
# Means: Condition
# wt       97.790182
# 27del    86.215823
# 854      88.272137
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 97.79018181554622 for condition wt at position 0
# Plotting mean 86.21582269314592 for condition 27del at position 1
# Plotting mean 88.27213727965481 for condition 854 at position 2
# T-test between wt and 27del (TOTALframe2frameresults.csv):
# t-statistic: 0.19400851155972387, p-value: 0.8482283992417656
#
# T-test between wt and 854 (TOTALframe2frameresults.csv):
# t-statistic: 0.04648413589115626, p-value: 0.9634660830262611
#
# T-test between 27del and 854 (TOTALframe2frameresults.csv):
# t-statistic: -0.2407536047625333, p-value: 0.8124669564604227
#
# ANOVA test (TOTALframe2frameresults.csv):
# F-statistic: 0.004095743263473927, p-value: 0.9959133288015989
# Means: Condition
# wt       0.831948
# 27del    0.793185
# 854      0.821757
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 0.8319477678046032 for condition wt at position 0
# Plotting mean 0.7931846432127045 for condition 27del at position 1
# Plotting mean 0.8217568874528222 for condition 854 at position 2
# T-test between wt and 27del (TOTALstart2endresults.csv):
# t-statistic: 0.19251192476080564, p-value: 0.8493839827512681
#
# T-test between wt and 854 (TOTALstart2endresults.csv):
# t-statistic: 0.046771512547113946, p-value: 0.9632403949158432
#
# T-test between 27del and 854 (TOTALstart2endresults.csv):
# t-statistic: -0.23733011400491896, p-value: 0.8150809447314487
#
# ANOVA test (TOTALstart2endresults.csv):
# F-statistic: 0.0046192117870062725, p-value: 0.9953923250866361
# Means: Condition
# wt       0.783940
# 27del    0.748119
# 854      0.774392
# Name: Mean, dtype: float64
# Condition folders: ['wt', '27del', '854']
# Plotting mean 0.7839399355047112 for condition wt at position 0
# Plotting mean 0.7481190324017697 for condition 27del at position 1
# Plotting mean 0.7743924766885547 for condition 854 at position 2
# No test was significant.

# %% [markdown]
# # Statistical Analysis for All Replicates
#
# Intended to be used on all replicates of an experiment that each have several conditions of data (cannot perform t-tests on one condition of data). Choose directory that contains all the folders for each replicate of experiment. Script will loop through each experimental replicate folder, open each condition folder, open kymoresults folder, then create take data and create a graph of the compiled results from each replicate of each metric, and perform t-tests and ANOVA on the MEAN results from each cell. Saves graphs and analysis results in new folder called 'results' in selected directory.

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, f_oneway
from tkinter import filedialog, Tk
import numpy as np

def analyze_data(directory, num_conditions, condition_names):
    significant_tests = False

    # Create a folder named "results" in the selected directory
    results_folder = os.path.join(directory, "results")
    os.makedirs(results_folder, exist_ok=True)

    # Define the files to read from each condition folder
    files_to_read = ['ANTdisplacementresults.csv', 'ANTdurationresults.csv', 'ANTframe2frameresults.csv',
                     'ANTstart2endresults.csv', 'RETdisplacementresults.csv', 'RETdurationresults.csv',
                     'RETframe2frameresults.csv', 'RETstart2endresults.csv', 'TOTALdisplacementresults.csv',
                     'TOTALdurationresults.csv', 'TOTALframe2frameresults.csv', 'TOTALstart2endresults.csv']

    # Create dictionaries to hold dataframes for each condition and file type
    condition_dfs = {condition_name: {file: pd.DataFrame() for file in files_to_read} for condition_name in condition_names}

    # Iterate over subfolders in the directory
    subfolders = [subfolder for subfolder in os.listdir(directory) if os.path.isdir(os.path.join(directory, subfolder))]
    for subfolder in subfolders:
        print(f"Processing subfolder: {subfolder}")
        # Iterate over condition folders
        for condition_name in condition_names:
            condition_folder = os.path.join(directory, subfolder, condition_name)
            if os.path.exists(condition_folder):
                print(f"Processing condition folder: {condition_folder}")
                # Read data from each file and append to respective dataframes
                for file in files_to_read:
                    file_path = os.path.join(condition_folder, 'kymoresults', file)
                    if os.path.exists(file_path):
                        print(f"Reading data from file: {file_path}")
                        df = pd.read_csv(file_path)
                        # Concatenate along columns (axis=1)
                        condition_dfs[condition_name][file] = pd.concat([condition_dfs[condition_name][file], df], ignore_index=True, axis=1)

    # Save dataframes to Excel files
    for condition_name, files_data in condition_dfs.items():
        print(f"\nSaving data for condition: {condition_name}")
        for file, df in files_data.items():
            output_file = os.path.join(results_folder, f'{condition_name}{file.split(".")[0]}.xlsx')
            df.to_excel(output_file, index=False)
            print(f"Saved data for {condition_name} - {file.split(".")[0]} to {output_file}")

    for key in files_to_read:
        key_name = os.path.splitext(key)[0]
        condition_dataframes = [condition_dfs[condition_name][key] for condition_name in condition_names]

        combined_summary = pd.concat([df.describe().loc['mean'] for df in condition_dataframes], axis=1)
        combined_summary.columns = condition_names

        t_test_results = []
        for i in range(len(condition_names)):
            for j in range(i + 1, len(condition_names)):
                t_stat, p_value = ttest_ind(combined_summary[condition_names[i]], combined_summary[condition_names[j]], nan_policy='omit')
                t_test_results.append((f"T-test between {condition_names[i]} and {condition_names[j]} ({key_name}):", f"t-statistic: {t_stat}, p-value: {p_value}"))
                print(f"\nT-test between {condition_names[i]} and {condition_names[j]} ({key_name}):")
                print(f"t-statistic: {t_stat}, p-value: {p_value}")

                if p_value < 0.05:
                    significant_tests = True

        # Drop rows with missing values
        clean_combined = combined_summary.dropna()

        anova_f_stat, anova_p_value = f_oneway(*[clean_combined[column] for column in clean_combined.columns])
        anova_result = f"ANOVA test ({key_name}): F-statistic: {anova_f_stat}, p-value: {anova_p_value}"

        print(f"\nANOVA test ({key_name}):")
        print(f"F-statistic: {anova_f_stat}, p-value: {anova_p_value}")

        if anova_p_value < 0.05:
            significant_tests = True

        # Write the results to a text file
        with open(os.path.join(results_folder, f"{key_name}_test_results.txt"), "w") as f:
            for result in t_test_results:
                f.write(result[0] + "\n")
                f.write(result[1] + "\n")
            f.write("\n")
            f.write(anova_result + "\n")
            f.write("\n")

        # Reshape the data for the violin plot
        combined_summary = combined_summary.reset_index().melt(id_vars='index', var_name='Condition', value_name='Mean')

        palette1 = sns.color_palette("flare", n_colors=len(condition_names))

        # Create violin plot
        plt.figure(figsize=(6, 6))

        # Draw violin plot with mean line
        sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw=0.2,
                       palette=palette1, linewidth=0, inner=None)  # Remove inner annotations to add mean line separately

        # Calculate mean for each group
        means = combined_summary.groupby('Condition')['Mean'].mean()
        means = means.reindex(condition_names)
        for i, mean_val in enumerate(means):
            plt.plot(i, mean_val, marker='D', color='black')  # Draw mean point

        plt.title(f'{"Anterograde" if "ANT" in key_name else "Retrograde" if "RET" in key_name else "Total"} '
                  f'{"Duration" if "duration" in key_name else "Displacement" if "displacement" in key_name else "Frame2Frame Velocity" if "frame2frame" in key_name else "Start2End Velocity"}', 
                  fontsize=16, fontweight='bold')

        plt.ylabel(f'{"Track Mean Velocity [µm/sec]" if "2" in key_name else "Track Duration [sec]" if "duration" in key_name else "Track Displacement [µm]"} ', fontsize=16, fontweight='bold')
        plt.xlabel('')
        plt.xticks(np.arange(len(means)), means.index, fontsize=12, fontweight='bold')  # Set ticks at each group
        plt.yticks(fontsize=12, fontweight='bold')
        plt.gca().spines['top'].set_visible(False)
        plt.gca().spines['right'].set_visible(False)
        plt.gca().spines['left'].set_linewidth(2)
        plt.gca().spines['bottom'].set_linewidth(2)

        plt.tight_layout()
        # Save the plot to the results folder
        plt.savefig(os.path.join(results_folder, f'{key_name}_summary.png'))
        plt.show()
        plt.close()

    if significant_tests:
        print("\nAt least one test was significant.")
    else:
        print("\nNo test was significant.")

# Prompt the user for the number of conditions and their names
num_conditions = int(input("Enter the number of conditions: "))

condition_names = []
for i in range(num_conditions):
    condition_name = input(f"Enter the name for condition {i + 1}: ")
    condition_names.append(condition_name)

# Create the tkinter window
root = Tk()
root.withdraw()  # Hide the main window

# Ask the user to select a directory
directory = filedialog.askdirectory(title="Select Directory Containing Subfolders with Condition Folders")

# Perform analysis if a directory is selected
if directory:
    analyze_data(directory, num_conditions, condition_names)
else:
    print("No directory selected.")

# %% [markdown]
# # test

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, f_oneway
from tkinter import filedialog, Tk
import numpy as np

def analyze_data(directory, num_conditions, condition_names, normalize):
    significant_tests = False

    # Define results folder based on normalization
    results_folder = os.path.join(directory, "results_normalized" if normalize else "results")
    os.makedirs(results_folder, exist_ok=True)

    # Define the files to read from each condition folder
    files_to_read = ['ANTdisplacementresults.csv', 'ANTdurationresults.csv', 'ANTframe2frameresults.csv',
                     'ANTstart2endresults.csv', 'RETdisplacementresults.csv', 'RETdurationresults.csv',
                     'RETframe2frameresults.csv', 'RETstart2endresults.csv', 'TOTALdisplacementresults.csv',
                     'TOTALdurationresults.csv', 'TOTALframe2frameresults.csv', 'TOTALstart2endresults.csv']

    # Create dictionaries to hold dataframes for each condition and file type
    condition_dfs = {condition_name: {file: pd.DataFrame() for file in files_to_read} for condition_name in condition_names}

    # Iterate over subfolders in the directory
    subfolders = [subfolder for subfolder in os.listdir(directory) if os.path.isdir(os.path.join(directory, subfolder))]
    for subfolder in subfolders:
        print(f"Processing subfolder: {subfolder}")
        # Iterate over condition folders
        for condition_name in condition_names:
            condition_folder = os.path.join(directory, subfolder, condition_name)
            if os.path.exists(condition_folder):
                print(f"Processing condition folder: {condition_folder}")
                # Read data from each file and append to respective dataframes
                for file in files_to_read:
                    file_path = os.path.join(condition_folder, 'kymoresults', file)
                    if os.path.exists(file_path):
                        df = pd.read_csv(file_path)
                        # Concatenate along columns (axis=1)
                        condition_dfs[condition_name][file] = pd.concat([condition_dfs[condition_name][file], df], ignore_index=True, axis=1)

    # Normalize means if user opted to normalize data
    if normalize:
        for condition_name, files_data in condition_dfs.items():
            normalization_factor = files_data[files_to_read[0]].mean().mean() / condition_dfs[condition_names[0]][files_to_read[0]].mean().mean()
            for file, df in files_data.items():
                condition_dfs[condition_name][file] = df * normalization_factor


    # Save dataframes to Excel files
    for condition_name, files_data in condition_dfs.items():
        print(f"\nSaving data for condition: {condition_name}")
        for file, df in files_data.items():
            output_file = os.path.join(results_folder, f'{condition_name}{file.split(".")[0]}.xlsx')
            df.to_excel(output_file, index=False)
            print(f"Saved data for {condition_name} - {file.split(".")[0]} to {output_file}")

    for key in files_to_read:
        key_name = os.path.splitext(key)[0]
        condition_dataframes = [condition_dfs[condition_name][key] for condition_name in condition_names]

        combined_summary = pd.concat([df.describe().loc['mean'] for df in condition_dataframes], axis=1)
        combined_summary.columns = condition_names

        t_test_results = []
        for i in range(len(condition_names)):
            for j in range(i + 1, len(condition_names)):
                t_stat, p_value = ttest_ind(combined_summary[condition_names[i]], combined_summary[condition_names[j]], nan_policy='omit')
                t_test_results.append((f"T-test between {condition_names[i]} and {condition_names[j]} ({key_name}):", f"t-statistic: {t_stat}, p-value: {p_value}"))
                print(f"\nT-test between {condition_names[i]} and {condition_names[j]} ({key_name}):")
                print(f"t-statistic: {t_stat}, p-value: {p_value}")

                if p_value < 0.05:
                    significant_tests = True

        # Drop rows with missing values
        clean_combined = combined_summary.dropna()

        anova_f_stat, anova_p_value = f_oneway(*[clean_combined[column] for column in clean_combined.columns])
        anova_result = f"ANOVA test ({key_name}): F-statistic: {anova_f_stat}, p-value: {anova_p_value}"

        print(f"\nANOVA test ({key_name}):")
        print(f"F-statistic: {anova_f_stat}, p-value: {anova_p_value}")

        if anova_p_value < 0.05:
            significant_tests = True

        # Write the results to a text file
        with open(os.path.join(results_folder, f"{key_name}_test_results.txt"), "w") as f:
            for result in t_test_results:
                f.write(result[0] + "\n")
                f.write(result[1] + "\n")
            f.write("\n")
            f.write(anova_result + "\n")
            f.write("\n")

        # Reshape the data for the violin plot
        combined_summary = combined_summary.reset_index().melt(id_vars='index', var_name='Condition', value_name='Mean')

        palette1 = sns.color_palette("flare", n_colors=len(condition_names))

        # Create violin plot
        plt.figure(figsize=(6, 6))

        # Draw violin plot with mean line
        sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
                       palette=palette1, linewidth=0, inner=None)  # Remove inner annotations to add mean line separately

        # Calculate mean for each group
        means = combined_summary.groupby('Condition')['Mean'].mean()
        means = means.reindex(condition_names)
        for i, mean_val in enumerate(means):
            plt.plot(i, mean_val, marker='D', color='black')  # Draw mean point

        plt.title(f'{"Anterograde" if "ANT" in key_name else "Retrograde" if "RET" in key_name else "Total"} '
                  f'{"Duration" if "duration" in key_name else "Displacement" if "displacement" in key_name else "Frame2Frame Velocity" if "frame2frame" in key_name else "Start2End Velocity"}', 
                  fontsize=16, fontweight='bold')

        plt.ylabel(f'{"Track Mean Velocity [µm/sec]" if "2" in key_name else "Track Duration [sec]" if "duration" in key_name else "Track Displacement [µm]"} ', fontsize=16, fontweight='bold')
        plt.xlabel('')
        plt.xticks(np.arange(len(means)), means.index, fontsize=12, fontweight='bold')  # Set ticks at each group
        plt.yticks(fontsize=12, fontweight='bold')
        plt.gca().spines['top'].set_visible(False)
        plt.gca().spines['right'].set_visible(False)
        plt.gca().spines['left'].set_linewidth(2)
        plt.gca().spines['bottom'].set_linewidth(2)

        plt.tight_layout()
        # Save the plot to the results folder
        plt.savefig(os.path.join(results_folder, f'{key_name}_summary.png'))
        plt.show()
        plt.close()

    if significant_tests:
        print("\nAt least one test was significant.")
    else:
        print("\nNo test was significant.")

# Prompt the user for the number of conditions and their names
num_conditions = int(input("Enter the number of conditions: "))

condition_names = []
for i in range(num_conditions):
    condition_name = input(f"Enter the name for condition {i + 1}: ")
    condition_names.append(condition_name)

# Ask the user if they want to normalize the data
normalize = input("Do you want to normalize the data? (yes/no): ").strip().lower() == 'yes'

# Create the tkinter window
root = Tk()
root.withdraw()  # Hide the main window

# Ask the user to select a directory
directory = filedialog.askdirectory(title="Select Directory Containing Subfolders with Condition Folders")

# Perform analysis if a directory is selected
if directory:
    analyze_data(directory, num_conditions, condition_names, normalize)
else:
    print("No directory selected.")
# Out:
# Processing subfolder: 5.10.24 pcdna mscarlet lamp, 5a halo, gen3, 0.5ugDNA
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.10.24 pcdna mscarlet lamp, 5a halo, gen3, 0.5ugDNA\wt
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.10.24 pcdna mscarlet lamp, 5a halo, gen3, 0.5ugDNA\27del
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.10.24 pcdna mscarlet lamp, 5a halo, gen3, 0.5ugDNA\854
# Processing subfolder: 5.16.24 pcdna mscarlet lamp, 5a halo, gen4, 0.5ug DNA
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.16.24 pcdna mscarlet lamp, 5a halo, gen4, 0.5ug DNA\wt
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.16.24 pcdna mscarlet lamp, 5a halo, gen4, 0.5ug DNA\27del
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.16.24 pcdna mscarlet lamp, 5a halo, gen4, 0.5ug DNA\854
# Processing subfolder: 5.3.24 pcdna mScarlet Lamp, 5A HALO, gen1, (1ugDNA)
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.3.24 pcdna mScarlet Lamp, 5A HALO, gen1, (1ugDNA)\wt
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.3.24 pcdna mScarlet Lamp, 5A HALO, gen1, (1ugDNA)\27del
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.3.24 pcdna mScarlet Lamp, 5A HALO, gen1, (1ugDNA)\854
# Processing subfolder: 5.6.24 pcdna mscarlet lamp, 5a halo, gen2 (1ugDNA)
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.6.24 pcdna mscarlet lamp, 5a halo, gen2 (1ugDNA)\wt
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.6.24 pcdna mscarlet lamp, 5a halo, gen2 (1ugDNA)\27del
# Processing condition folder: C:/Users/oes6098/Desktop/test lysos2\5.6.24 pcdna mscarlet lamp, 5a halo, gen2 (1ugDNA)\854
# Processing subfolder: results
# Processing subfolder: results_normalized
#
# Saving data for condition: wt
# Saved data for wt - ANTdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\wtANTdisplacementresults.xlsx
# Saved data for wt - ANTdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\wtANTdurationresults.xlsx
# Saved data for wt - ANTframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\wtANTframe2frameresults.xlsx
# Saved data for wt - ANTstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\wtANTstart2endresults.xlsx
# Saved data for wt - RETdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\wtRETdisplacementresults.xlsx
# Saved data for wt - RETdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\wtRETdurationresults.xlsx
# Saved data for wt - RETframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\wtRETframe2frameresults.xlsx
# Saved data for wt - RETstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\wtRETstart2endresults.xlsx
# Saved data for wt - TOTALdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\wtTOTALdisplacementresults.xlsx
# Saved data for wt - TOTALdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\wtTOTALdurationresults.xlsx
# Saved data for wt - TOTALframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\wtTOTALframe2frameresults.xlsx
# Saved data for wt - TOTALstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\wtTOTALstart2endresults.xlsx
#
# Saving data for condition: 27del
# Saved data for 27del - ANTdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\27delANTdisplacementresults.xlsx
# Saved data for 27del - ANTdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\27delANTdurationresults.xlsx
# Saved data for 27del - ANTframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\27delANTframe2frameresults.xlsx
# Saved data for 27del - ANTstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\27delANTstart2endresults.xlsx
# Saved data for 27del - RETdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\27delRETdisplacementresults.xlsx
# Saved data for 27del - RETdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\27delRETdurationresults.xlsx
# Saved data for 27del - RETframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\27delRETframe2frameresults.xlsx
# Saved data for 27del - RETstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\27delRETstart2endresults.xlsx
# Saved data for 27del - TOTALdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\27delTOTALdisplacementresults.xlsx
# Saved data for 27del - TOTALdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\27delTOTALdurationresults.xlsx
# Saved data for 27del - TOTALframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\27delTOTALframe2frameresults.xlsx
# Saved data for 27del - TOTALstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\27delTOTALstart2endresults.xlsx
#
# Saving data for condition: 854
# Saved data for 854 - ANTdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\854ANTdisplacementresults.xlsx
# Saved data for 854 - ANTdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\854ANTdurationresults.xlsx
# Saved data for 854 - ANTframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\854ANTframe2frameresults.xlsx
# Saved data for 854 - ANTstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\854ANTstart2endresults.xlsx
# Saved data for 854 - RETdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\854RETdisplacementresults.xlsx
# Saved data for 854 - RETdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\854RETdurationresults.xlsx
# Saved data for 854 - RETframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\854RETframe2frameresults.xlsx
# Saved data for 854 - RETstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\854RETstart2endresults.xlsx
# Saved data for 854 - TOTALdisplacementresults to C:/Users/oes6098/Desktop/test lysos2\results\854TOTALdisplacementresults.xlsx
# Saved data for 854 - TOTALdurationresults to C:/Users/oes6098/Desktop/test lysos2\results\854TOTALdurationresults.xlsx
# Saved data for 854 - TOTALframe2frameresults to C:/Users/oes6098/Desktop/test lysos2\results\854TOTALframe2frameresults.xlsx
# Saved data for 854 - TOTALstart2endresults to C:/Users/oes6098/Desktop/test lysos2\results\854TOTALstart2endresults.xlsx
#
# T-test between wt and 27del (ANTdisplacementresults):
# t-statistic: -0.34583155944700855, p-value: 0.7303138752328184
#
# T-test between wt and 854 (ANTdisplacementresults):
# t-statistic: 0.8832020170526129, p-value: 0.37964784559217835
#
# T-test between 27del and 854 (ANTdisplacementresults):
# t-statistic: 1.4246376061734685, p-value: 0.15788081290577188
#
# ANOVA test (ANTdisplacementresults):
# F-statistic: 0.7424216521555602, p-value: 0.47803028260262215
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (ANTdurationresults):
# t-statistic: 0.9314821810996636, p-value: 0.3542117888238724
#
# T-test between wt and 854 (ANTdurationresults):
# t-statistic: 0.2647642827693026, p-value: 0.791839645633587
#
# T-test between 27del and 854 (ANTdurationresults):
# t-statistic: -0.6557454607022389, p-value: 0.5137384029841601
#
# ANOVA test (ANTdurationresults):
# F-statistic: 0.4714818725912971, p-value: 0.6251733057790767
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (ANTframe2frameresults):
# t-statistic: -0.7033205373563849, p-value: 0.4837557626243849
#
# T-test between wt and 854 (ANTframe2frameresults):
# t-statistic: 0.5630826392142875, p-value: 0.5748785475948559
#
# T-test between 27del and 854 (ANTframe2frameresults):
# t-statistic: 1.4166852370657692, p-value: 0.16018723084978417
#
# ANOVA test (ANTframe2frameresults):
# F-statistic: 0.8020928410445638, p-value: 0.4506655476573683
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (ANTstart2endresults):
# t-statistic: -0.6949676478233415, p-value: 0.488949038513384
#
# T-test between wt and 854 (ANTstart2endresults):
# t-statistic: 0.5430545820042856, p-value: 0.5885303705253966
#
# T-test between 27del and 854 (ANTstart2endresults):
# t-statistic: 1.38305800638865, p-value: 0.17022740689743976
#
# ANOVA test (ANTstart2endresults):
# F-statistic: 0.7652321167792151, p-value: 0.4673756527211206
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (RETdisplacementresults):
# t-statistic: -0.0747222217860956, p-value: 0.9406092643818222
#
# T-test between wt and 854 (RETdisplacementresults):
# t-statistic: 0.595377216489205, p-value: 0.5531920334456673
#
# T-test between 27del and 854 (RETdisplacementresults):
# t-statistic: 0.7436544790654434, p-value: 0.45911244492964587
#
# ANOVA test (RETdisplacementresults):
# F-statistic: 0.3871288910479127, p-value: 0.6798083854705752
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (RETdurationresults):
# t-statistic: 0.14651802101505362, p-value: 0.8838553788621876
#
# T-test between wt and 854 (RETdurationresults):
# t-statistic: 0.2839537943494213, p-value: 0.7771445377521332
#
# T-test between 27del and 854 (RETdurationresults):
# t-statistic: 0.1213012206015154, p-value: 0.903735428316911
#
# ANOVA test (RETdurationresults):
# F-statistic: 0.03632206719237545, p-value: 0.9643397577770721
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (RETframe2frameresults):
# t-statistic: 0.09941287348782908, p-value: 0.9210418302999337
#
# T-test between wt and 854 (RETframe2frameresults):
# t-statistic: 0.6148866317685813, p-value: 0.540291735143677
#
# T-test between 27del and 854 (RETframe2frameresults):
# t-statistic: 0.5948741443104654, p-value: 0.5534895905071421
#
# ANOVA test (RETframe2frameresults):
# F-statistic: 0.310597880500133, p-value: 0.7335681723772571
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (RETstart2endresults):
# t-statistic: 0.08651033878402459, p-value: 0.9312618407706382
#
# T-test between wt and 854 (RETstart2endresults):
# t-statistic: 0.6230460138643746, p-value: 0.5349422524674254
#
# T-test between 27del and 854 (RETstart2endresults):
# t-statistic: 0.6187457042339054, p-value: 0.5377193866632364
#
# ANOVA test (RETstart2endresults):
# F-statistic: 0.32353583816462084, p-value: 0.7241853478545
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (TOTALdisplacementresults):
# t-statistic: -0.3412973437901232, p-value: 0.7337122234727672
#
# T-test between wt and 854 (TOTALdisplacementresults):
# t-statistic: 0.7337195084567695, p-value: 0.46516267622467444
#
# T-test between 27del and 854 (TOTALdisplacementresults):
# t-statistic: 1.2465340845249966, p-value: 0.21595300949182808
#
# ANOVA test (TOTALdisplacementresults):
# F-statistic: 0.6361499615183667, p-value: 0.5310178617712693
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (TOTALdurationresults):
# t-statistic: 0.2719204579753924, p-value: 0.7863349157293364
#
# T-test between wt and 854 (TOTALdurationresults):
# t-statistic: 0.3883838733213237, p-value: 0.6987145908129568
#
# T-test between 27del and 854 (TOTALdurationresults):
# t-statistic: 0.09180350954329536, p-value: 0.9270676621924229
#
# ANOVA test (TOTALdurationresults):
# F-statistic: 0.08427619238132918, p-value: 0.9192291195297763
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (TOTALframe2frameresults):
# t-statistic: -0.36546778146776016, p-value: 0.7156596043201122
#
# T-test between wt and 854 (TOTALframe2frameresults):
# t-statistic: 0.5480410879474905, p-value: 0.5851171693497454
#
# T-test between 27del and 854 (TOTALframe2frameresults):
# t-statistic: 1.0556189959861813, p-value: 0.2940988263716107
#
# ANOVA test (TOTALframe2frameresults):
# F-statistic: 0.5151946001468729, p-value: 0.5986372462348779
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# T-test between wt and 27del (TOTALstart2endresults):
# t-statistic: -0.3722973578902581, p-value: 0.7105873325744638
#
# T-test between wt and 854 (TOTALstart2endresults):
# t-statistic: 0.532911251189049, p-value: 0.5955020910311668
#
# T-test between 27del and 854 (TOTALstart2endresults):
# t-statistic: 1.0454963496330956, p-value: 0.2987233657916209
#
# ANOVA test (TOTALstart2endresults):
# F-statistic: 0.5065164830885127, p-value: 0.6038127477257654
# C:\Users\oes6098\AppData\Local\Temp\ipykernel_12344\2567027128.py:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y='Mean', data=combined_summary, bw_method=0.2,
# No test was significant.
